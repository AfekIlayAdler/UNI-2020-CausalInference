# %%
import numpy as np
# !pip install tensorboardcolab
import torch
from torchvision import datasets, transforms
import helper
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import summary
import datetime
import pandas as pd
from collections import OrderedDict
from os import mkdir
from os.path import isdir
from glob import glob
from pathlib import Path
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from google.colab import drive
import seaborn as sns
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read input data

# %%
ROOT_PATH = Path('/content/drive/My Drive/DL/Project/experiments/ate/')
DATA_PATH = ROOT_PATH/'data/' 
SEED = 42

x = pd.read_csv(DATA_PATH/'X_one_hot.csv')
gestat_simulated = pd.read_csv(DATA_PATH/'gestat10.csv',header = None)[0]
heavier_tween_first = pd.read_csv(DATA_PATH/'heavier_tween_born_first.csv',header = None)[0]
y = pd.read_csv(DATA_PATH/'Y.csv')

# %% [markdown]
# ## Simulate observational study

# %%
def get_simulated_data(x,y,gestat10, w_0, w_h,heavier_tween_first):
    p_heavier =  x@w_0 + w_h*(gestat10.astype('float')*0.1-0.1)
    p_heavier_norm = (p_heavier - p_heavier.min()) / (p_heavier.max() - p_heavier.min())
    t_s = (np.random.random(x.shape[0]) < p_heavier_norm)*1 # t = 1 means heavier
    y_s = []
    birth_order = []
    for i,tween in enumerate(t_s):
        y_s.append(y.values[i,tween])
        if tween == 1: # if the hevier tween 
            is_hevier = heavier_tween_first[i]
        else:
            is_hevier = not heavier_tween_first[i]
        birth_order.append(is_hevier*1)
    temp_x = x.copy()
    temp_x["birth_order"] =  birth_order
    return temp_x,np.array(y_s),t_s

# %% [markdown]
# ## Propensity score model

# %%
class PS_NN(nn.Module):
  def __init__(self):
    super().__init__() 
    self.fc1 = nn.Linear(163, 20) 
    self.fc2 = nn.Linear(20, 20) 
    self.fc3 = nn.Linear(20, 2) 
    self.fc4 = nn.Linear(163, 2) 
    self.softmax = nn.LogSoftmax(dim=1)
    self.regulizer = nn.Dropout(0.01)

  def forward(self, x):
    # x = F.relu(self.fc1(x)) 
    # x = self.regulizer(x) 
    # x = F.relu(self.fc2(x)) 
    # x = self.regulizer(x) 
    # x = F.relu(self.fc3(x)) 
    # x= self.softmax(x)
    x = self.softmax(self.fc4(x))
    return x

# %% [markdown]
# ## Trainer

# %%
from sklearn.model_selection import train_test_split

def get_batch(x,y,batch_size,device):
  batches = np.arange(0,x.shape[0],batch_size)
  for i in range(len(batches)-1):
    inputs, targets = torch.from_numpy(x[batches[i]:batches[i+1],:]), torch.from_numpy(y[batches[i]:batches[i+1]])
    inputs = inputs.to(device).float()
    targets = targets.to(device, dtype=torch.int64)
    yield inputs, targets

class Trainer:
  def __init__(self,model, config):
    self.model = model
    self.model_name = config.model_name
    self.lr = config.lr
    self.epochs = config.epochs
    self.save_model = config.save_model
    self.upload_model = config.upload_model
    self.model_weights_path = config.model_weights_path
    self.batch_size =  config.batch_size
    self.dropout_std_n_times = config.dropout_std_n_times
    self.momentum = config.momentum
    self.optimizer = optim.SGD(self.model.parameters(), lr = self.lr, weight_decay = config.weight_decay, momentum=self.momentum)
    self.scheduler = optim.lr_scheduler.StepLR(self.optimizer, step_size=config.step_size, gamma=config.gamma)
    self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    class_weights = torch.FloatTensor([0.657,0.342]).to(self.device)
    self.criterion = nn.NLLLoss(weight=class_weights,reduction='none')
    self.results = {}
    self.sgd_spv_matrix = {}
    self.warmup_epochs = config.warmup_epochs
    self.eps = config.eps
    if torch.cuda.is_available():
      self.model.to(self.device)

  def get_results(self):
    return pd.DataFrame.from_dict(self.results)

  def record(self,epoch,**kwargs):
    epoch = "{:02d}".format(epoch)
    temp = f"| epoch   # {epoch} :"
    for key, value in kwargs.items():
      key = f"{self.model_name}_{key}"
      if not self.results.get(key):
        self.results[key] =[]
      self.results[key].append(value)
      val = '{:.4f}'.format(np.round(value,4))
      temp += f"{key} : {val}      |       "
    print(temp)


  def fit(self,x,y, exp_name): 
    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.12)
    train_accu, test_accu, output_plot = [],[],[]
    for epoch in range(1,self.epochs+1):
      weights_path = Path(f"{self.model_weights_path}/{config.model_name}_{epoch}.pth")
      train_metric, train_loss = self.run_epoch(x_train, y_train, epoch)
      validation_metric, validation_loss = self.val(x_val, y_val,epoch)
      self.record(epoch,
                  train_acc = train_metric,
                  train_loss = train_loss,
                  test_acc = validation_metric,
                  validation_loss = validation_loss)


  def run_epoch(self, x,y,epoch):
    self.model.train()
    train_loss , train_metric = 0, 0
    for batch , (inputs, labels) in enumerate(get_batch(x,y,self.batch_size,self.device)):
      loss = self.get_loss(inputs, labels, batch, epoch)  #self.weighted_loss(images, labels, i, epoch)
      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()
      self.scheduler.step()
      train_loss += self.get_loss(inputs, labels, i, epoch, False).item()
      train_metric += self.calc_accuracy(inputs,labels,return_labels=False)
    accuracy = train_metric/(batch+1)
    return accuracy,train_loss


  def val(self, x,y, epoch):
    self.model.eval()
    val_loss , val_metric = 0, 0
    with torch.no_grad():
      for batch , (inputs, labels) in enumerate(get_batch(x,y,self.batch_size,self.device)):
        acc = self.calc_accuracy(inputs,labels)
        val_metric += acc 
        val_loss += self.get_loss(inputs, labels, batch, epoch, False).item()
    acuuracy = val_metric/(batch+1)
    return acuuracy,val_loss

  def get_loss(self,x, y, batch, epoch,weighted=True):
    loss = self.criterion(self.model(x), y)
    weights = torch.ones(x.size()[0], device= self.device)
    if weighted and (epoch >= self.warmup_epochs + 1) and (self.model_name != 'baseline'):
        epoch_of_weighted_training = epoch - (self.warmup_epochs + 1) 
        weights = self.weighted_loss(x, y,batch, epoch_of_weighted_training) 
    return (loss*weights).mean()
    

  def weighted_loss(self, x, labels, batch, epoch_weighted, is_test=False):
    total_weighted_epochs = self.epochs - self.warmup_epochs
    batch_size = x.size()[0] 
    #row_indexes = [i for i in range(self.batch_size)]
    with torch.no_grad():
      weights = torch.ones(batch_size, device= self.device)

      if self.model_name == 'MCdropout' or is_test:  
        all_p =  torch.zeros((batch_size #self.batch_size,
                              ,self.dropout_std_n_times), device= self.device)
        for i in range(self.dropout_std_n_times):
          p = torch.exp(self.model(x))
          p_true_labels = torch.gather(p, 1, labels.view(-1,1))
          #p_true_labels = p[row_indexes,labels]
          all_p[:,i] = p_true_labels.view(-1)
          weights = all_p.std(axis = 1)

      elif self.model_name == 'entropy':
        log_p = self.model(x)
        weights = -torch.mul(log_p, torch.exp(log_p)).sum(axis = 1)

      elif self.model_name == 'SGD-WPV':
        self.sgd_spv_matrix.setdefault(batch, torch.zeros((batch_size #self.batch_size,
                                                          ,total_weighted_epochs), device= self.device))
        # update_matrix
        p = torch.exp(self.model(x))
        p_true_labels = torch.gather(p, 1, labels.view(-1,1))
        #p_true_labels = p[row_indexes,labels]
        self.sgd_spv_matrix[batch][:,epoch_weighted] = p_true_labels.view(-1)
        if epoch_weighted not in [0,1]:
          indexes = [i for i in range(epoch_weighted)]
          var = self.sgd_spv_matrix[batch][:,indexes].var(axis = 1)
          var +=  var.pow(2)/(len(indexes) -1)
          weights = var.sqrt()
        # else:
        #   weights = torch.ones(x.size()[0], device= self.device) # no history, or no variance -> equal weights
      weights += self.eps
      return (weights/weights.mean())


  def get_ps(self, x):
    with torch.no_grad():
      x = torch.from_numpy(x).to(self.device).float()
      return torch.exp(self.model(x)).cpu().numpy()[:,1]


  def calc_accuracy(self, images, labels, return_labels=False):
    self.model.eval()
    log_ps = self.model(images)
    ps = torch.exp(log_ps)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    acc = torch.mean(equals.type(torch.FloatTensor))
    if return_labels:
      predicted_lables = top_class.view(-1).cpu().tolist()
      ps_labels = torch.gather(ps, 1, labels.view(-1,1))
      self.model.train()
      return acc, predicted_lables, ps_labels.view(-1).cpu().tolist()
    self.model.train()
    return acc


  def save_checkpoint(self,weights_path,loss):
    if (not weights_path.exists()) and self.save_model: 
      torch.save({'model_state_dict': self.model.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),'loss': loss}, weights_path)
      
  def load_checkpoint(self,weights_path,epoch):
    checkpoint = torch.load(weights_path)
    self.model.load_state_dict(checkpoint['model_state_dict'])
    self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    self.model.to(self.device)
    loss = checkpoint['loss']
    print(f"Uploaded weights succesfuly at epoch number {epoch}")
    return loss

# %% [markdown]
# ## Utils

# %%
import time
def change_seed():
  t = 1000 * time.time() # current time in milliseconds
  np.random.seed(int(t) % 2**32)

def calculate_ate_ate_estimated(res):
  ate_hat = (res['y']*res['t']/res['ps'] -res['y']*(1-res['t'])/(1-res['ps'])).mean()
  ate_true = (res['mort_1']-res['mort_0']).mean()
  return ate_true, ate_hat

def calculate_ates(res,alpha = 0.1):
  ate_true, ate_hat = calculate_ate_ate_estimated(res)
  res = res[res['ps'].between(0+alpha, 1- alpha)]
  ate_true_with_alpha, ate_hat_with_alpha = calculate_ate_ate_estimated(res)
  return [ate_true, ate_hat, ate_true_with_alpha, ate_hat_with_alpha]
  # print(F"true ate is {ate_true} and estimated ate is {ate_hat}")


def get_results_df(propensity_score, t,y_simulated,y_all):
  results = pd.DataFrame()
  results['ps'] = propensity_score
  results['t'] = t
  results['y'] = y_simulated 
  return pd.concat([results,y_all], axis = 1)

class Config:  
  def __init__(self, **kwargs):
    for key, value in kwargs.items():
      setattr(self, key, value)

  def add_attributes(self,**kwargs):
    for key, value in kwargs.items():
      setattr(self, key, value)

# %% [markdown]
# ## Config

# %%
MODEL_WEIGHTS_DIR = 'model_weights'
GRAPHS_FOLDER_NAME = 'graphs'
model_weights_dir = f"{ROOT_PATH}{MODEL_WEIGHTS_DIR}" 
graphs_dir = f"{ROOT_PATH}{GRAPHS_FOLDER_NAME}" 
N_EXP = 10

def get_base_config():
  SAVE_TO_CHECKPOINTS = False
  LOAD_CHECKPOINTS = False 
  return Config(
          lr = 0.001,
          warmup_epochs = 1,
          epochs = 10,
          step_size=2,
          gamma=0.95,
          eps= 0.001,
          weight_decay=0.01,
          dropout_std_n_times = 15,
          momentum = 0.9,
          save_model = SAVE_TO_CHECKPOINTS,
          upload_model = LOAD_CHECKPOINTS,
          model_weights_path = model_weights_dir,
          batch_size = 16)
  
ate_columns =  ['ATE_TRUE_ALL_POPULATION', 'ATE_HAT_ALL_POPULATION', 'ATE_TRUE_POPULATION_BETWEEN [a,1-a]', 'ATE_HAT_POPULATION_BETWEEN [a,1-a]']
np.random.seed(SEED)
w_0 = np.random.normal(0,0.1,x.shape[1])
w_h = np.random.normal(3,0.1)
seeds = np.random.choice([i for i in range(100)],N_EXP,replace = False)

# %% [markdown]
# ## Run experiments

# %%
from sklearn.metrics import roc_auc_score
all_pop_ate = y['mort_1'].mean()- y['mort_0'].mean()
config = get_base_config()
all_ate = []
for exp in ['baseline','entropy','MCdropout','SGD-WPV']:
  ate = []
  for i in range(N_EXP):
    torch.manual_seed(seeds[i])
    # change_seed()
    X,Y,T = get_simulated_data(x,y,gestat_simulated, w_0, w_h,heavier_tween_first)
    X,T = X.values.astype('float64'),T.values.astype('float64')
    config.add_attributes(model_name = exp)
    trainer = Trainer(PS_NN(), config)
    trainer.fit(X,T, exp)
    ps = trainer.get_ps(X) 
    print(F"auc is {roc_auc_score(T, ps)}")
    results = get_results_df(ps, T,Y,y)
    ate.append(calculate_ates(results))
  ate = pd.DataFrame(ate,columns = ate_columns)
  ate['exp'] = exp
  all_ate.append(ate)
# Out:
# | epoch   # 01 :baseline_train_acc : 0.6425      |       baseline_train_loss : 217.4445      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 02 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 03 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 04 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 05 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 06 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 07 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 08 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 09 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# | epoch   # 10 :baseline_train_acc : 0.6451      |       baseline_train_loss : 215.8359      |       baseline_test_acc : 0.6617      |       baseline_validation_loss : 29.2991      |
# auc is 0.5034354683946378
# | epoch   # 01 :baseline_train_acc : 0.6443      |       baseline_train_loss : 217.8520      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 02 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 03 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 04 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 05 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 06 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 07 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 08 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 09 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# | epoch   # 10 :baseline_train_acc : 0.6463      |       baseline_train_loss : 216.1001      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 29.2941      |
# auc is 0.46900609505111357
# | epoch   # 01 :baseline_train_acc : 0.6563      |       baseline_train_loss : 215.4728      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 02 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 03 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 04 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 05 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 06 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 07 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 08 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 09 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# | epoch   # 10 :baseline_train_acc : 0.6592      |       baseline_train_loss : 213.1856      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 29.0459      |
# auc is 0.4980112138503292
# | epoch   # 01 :baseline_train_acc : 0.6500      |       baseline_train_loss : 218.7850      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 02 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 03 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 04 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 05 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 06 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 07 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 08 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 09 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# | epoch   # 10 :baseline_train_acc : 0.6556      |       baseline_train_loss : 215.3815      |       baseline_test_acc : 0.6463      |       baseline_validation_loss : 29.5526      |
# auc is 0.5024869080762911
# | epoch   # 01 :baseline_train_acc : 0.6483      |       baseline_train_loss : 214.1813      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 02 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 03 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 04 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 05 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 06 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 07 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 08 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 09 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# | epoch   # 10 :baseline_train_acc : 0.6491      |       baseline_train_loss : 212.4555      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.7782      |
# auc is 0.4917140710219487
# | epoch   # 01 :baseline_train_acc : 0.6457      |       baseline_train_loss : 214.5288      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 02 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 03 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 04 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 05 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 06 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 07 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 08 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 09 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# | epoch   # 10 :baseline_train_acc : 0.6476      |       baseline_train_loss : 212.9361      |       baseline_test_acc : 0.6450      |       baseline_validation_loss : 29.0614      |
# auc is 0.5288251640652378
# | epoch   # 01 :baseline_train_acc : 0.6577      |       baseline_train_loss : 217.9162      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 02 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 03 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 04 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 05 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 06 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 07 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 08 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 09 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# | epoch   # 10 :baseline_train_acc : 0.6634      |       baseline_train_loss : 214.6849      |       baseline_test_acc : 0.6546      |       baseline_validation_loss : 29.5030      |
# auc is 0.497332574711786
# | epoch   # 01 :baseline_train_acc : 0.6558      |       baseline_train_loss : 211.8485      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 02 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 03 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 04 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 05 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 06 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 07 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 08 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 09 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# | epoch   # 10 :baseline_train_acc : 0.6581      |       baseline_train_loss : 209.4681      |       baseline_test_acc : 0.6572      |       baseline_validation_loss : 28.4007      |
# auc is 0.5297403864519552
# | epoch   # 01 :baseline_train_acc : 0.6492      |       baseline_train_loss : 217.6528      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 02 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 03 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 04 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 05 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 06 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 07 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 08 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 09 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# | epoch   # 10 :baseline_train_acc : 0.6522      |       baseline_train_loss : 215.5496      |       baseline_test_acc : 0.6366      |       baseline_validation_loss : 29.6620      |
# auc is 0.45928996297617897
# | epoch   # 01 :baseline_train_acc : 0.6591      |       baseline_train_loss : 213.5535      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 02 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 03 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 04 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 05 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 06 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 07 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 08 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 09 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# | epoch   # 10 :baseline_train_acc : 0.6613      |       baseline_train_loss : 211.2396      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 28.5984      |
# auc is 0.5003515077265209
# | epoch   # 01 :entropy_train_acc : 0.6516      |       entropy_train_loss : 214.6420      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 02 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 03 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 04 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 05 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 06 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 07 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 08 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 09 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# | epoch   # 10 :entropy_train_acc : 0.6532      |       entropy_train_loss : 212.8243      |       entropy_test_acc : 0.6862      |       entropy_validation_loss : 28.7244      |
# auc is 0.5052548186272909
# | epoch   # 01 :entropy_train_acc : 0.6540      |       entropy_train_loss : 213.9382      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 02 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 03 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 04 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 05 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 06 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 07 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 08 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 09 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# | epoch   # 10 :entropy_train_acc : 0.6562      |       entropy_train_loss : 211.7249      |       entropy_test_acc : 0.6469      |       entropy_validation_loss : 28.9080      |
# auc is 0.4688189699338807
# | epoch   # 01 :entropy_train_acc : 0.6475      |       entropy_train_loss : 216.8270      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 02 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 03 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 04 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 05 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 06 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 07 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 08 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 09 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# | epoch   # 10 :entropy_train_acc : 0.6512      |       entropy_train_loss : 214.6186      |       entropy_test_acc : 0.6591      |       entropy_validation_loss : 28.8143      |
# auc is 0.5010791885246979
# | epoch   # 01 :entropy_train_acc : 0.6444      |       entropy_train_loss : 221.8651      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 02 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 03 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 04 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 05 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 06 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 07 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 08 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 09 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# | epoch   # 10 :entropy_train_acc : 0.6506      |       entropy_train_loss : 218.8204      |       entropy_test_acc : 0.6546      |       entropy_validation_loss : 29.6707      |
# auc is 0.4974525610872213
# | epoch   # 01 :entropy_train_acc : 0.6580      |       entropy_train_loss : 213.4052      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 02 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 03 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 04 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 05 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 06 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 07 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 08 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 09 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# | epoch   # 10 :entropy_train_acc : 0.6581      |       entropy_train_loss : 211.6992      |       entropy_test_acc : 0.6372      |       entropy_validation_loss : 29.2437      |
# auc is 0.48574960514037835
# | epoch   # 01 :entropy_train_acc : 0.6496      |       entropy_train_loss : 212.2143      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 02 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 03 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 04 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 05 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 06 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 07 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 08 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 09 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# | epoch   # 10 :entropy_train_acc : 0.6505      |       entropy_train_loss : 210.3968      |       entropy_test_acc : 0.6521      |       entropy_validation_loss : 28.4439      |
# auc is 0.5396662433417838
# | epoch   # 01 :entropy_train_acc : 0.6465      |       entropy_train_loss : 220.2980      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 02 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 03 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 04 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 05 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 06 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 07 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 08 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 09 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# | epoch   # 10 :entropy_train_acc : 0.6522      |       entropy_train_loss : 217.2898      |       entropy_test_acc : 0.6392      |       entropy_validation_loss : 29.8019      |
# auc is 0.48892444078368996
# | epoch   # 01 :entropy_train_acc : 0.6512      |       entropy_train_loss : 215.2345      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 02 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 03 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 04 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 05 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 06 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 07 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 08 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 09 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# | epoch   # 10 :entropy_train_acc : 0.6533      |       entropy_train_loss : 213.2193      |       entropy_test_acc : 0.6604      |       entropy_validation_loss : 29.0613      |
# auc is 0.5280839006935147
# | epoch   # 01 :entropy_train_acc : 0.6559      |       entropy_train_loss : 216.4758      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 02 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 03 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 04 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 05 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 06 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 07 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 08 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 09 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# | epoch   # 10 :entropy_train_acc : 0.6582      |       entropy_train_loss : 214.3472      |       entropy_test_acc : 0.6566      |       entropy_validation_loss : 29.1556      |
# auc is 0.4650449705587285
# | epoch   # 01 :entropy_train_acc : 0.6608      |       entropy_train_loss : 213.2405      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 02 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 03 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 04 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 05 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 06 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 07 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 08 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 09 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# | epoch   # 10 :entropy_train_acc : 0.6633      |       entropy_train_loss : 210.9157      |       entropy_test_acc : 0.6579      |       entropy_validation_loss : 28.7009      |
# auc is 0.5059510567890265
# | epoch   # 01 :MCdropout_train_acc : 0.6541      |       MCdropout_train_loss : 213.8296      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 02 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 03 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 04 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 05 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 06 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 07 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 08 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 09 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# | epoch   # 10 :MCdropout_train_acc : 0.6564      |       MCdropout_train_loss : 211.9615      |       MCdropout_test_acc : 0.6611      |       MCdropout_validation_loss : 28.8083      |
# auc is 0.5122028581213968
# | epoch   # 01 :MCdropout_train_acc : 0.6582      |       MCdropout_train_loss : 214.7564      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 02 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 03 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 04 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 05 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 06 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 07 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 08 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 09 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# | epoch   # 10 :MCdropout_train_acc : 0.6606      |       MCdropout_train_loss : 212.7745      |       MCdropout_test_acc : 0.6534      |       MCdropout_validation_loss : 29.0580      |
# auc is 0.4731375674836165
# | epoch   # 01 :MCdropout_train_acc : 0.6494      |       MCdropout_train_loss : 219.0786      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 02 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 03 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 04 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 05 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 06 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 07 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 08 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 09 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# | epoch   # 10 :MCdropout_train_acc : 0.6518      |       MCdropout_train_loss : 217.0256      |       MCdropout_test_acc : 0.6559      |       MCdropout_validation_loss : 29.3679      |
# auc is 0.49617621999635064
# | epoch   # 01 :MCdropout_train_acc : 0.6498      |       MCdropout_train_loss : 218.8332      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 02 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 03 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 04 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 05 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 06 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 07 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 08 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 09 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# | epoch   # 10 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 215.4464      |       MCdropout_test_acc : 0.6591      |       MCdropout_validation_loss : 29.4154      |
# auc is 0.492624367884825
# | epoch   # 01 :MCdropout_train_acc : 0.6567      |       MCdropout_train_loss : 213.0943      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 02 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 03 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 04 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 05 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 06 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 07 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 08 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 09 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# | epoch   # 10 :MCdropout_train_acc : 0.6577      |       MCdropout_train_loss : 211.3121      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 28.8227      |
# auc is 0.48810406881418456
# ...
# | epoch   # 07 :SGD-WPV_train_acc : 0.6570      |       SGD-WPV_train_loss : 214.4462      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.9737      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6570      |       SGD-WPV_train_loss : 214.4462      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.9737      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6570      |       SGD-WPV_train_loss : 214.4462      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.9737      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6570      |       SGD-WPV_train_loss : 214.4462      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.9737      |
# auc is 0.47632011385286865
# | epoch   # 01 :SGD-WPV_train_acc : 0.6523      |       SGD-WPV_train_loss : 216.5017      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6565      |       SGD-WPV_train_loss : 214.4797      |       SGD-WPV_test_acc : 0.6514      |       SGD-WPV_validation_loss : 29.5015      |
# auc is 0.5145172320390271
# | epoch   # 01 :SGD-WPV_train_acc : 0.6469      |       SGD-WPV_train_loss : 218.6162      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6542      |       SGD-WPV_train_loss : 215.1376      |       SGD-WPV_test_acc : 0.6398      |       SGD-WPV_validation_loss : 29.3935      |
# auc is 0.4951485516487943
# | epoch   # 01 :SGD-WPV_train_acc : 0.6517      |       SGD-WPV_train_loss : 213.0083      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6528      |       SGD-WPV_train_loss : 211.1589      |       SGD-WPV_test_acc : 0.6443      |       SGD-WPV_validation_loss : 28.8942      |
# auc is 0.4906653574412433
# | epoch   # 01 :SGD-WPV_train_acc : 0.6525      |       SGD-WPV_train_loss : 213.2340      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6526      |       SGD-WPV_train_loss : 211.5188      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 28.6910      |
# auc is 0.5389426860956961
# | epoch   # 01 :SGD-WPV_train_acc : 0.6506      |       SGD-WPV_train_loss : 218.2596      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6559      |       SGD-WPV_train_loss : 214.9570      |       SGD-WPV_test_acc : 0.6894      |       SGD-WPV_validation_loss : 28.7126      |
# auc is 0.49572739606362237
# | epoch   # 01 :SGD-WPV_train_acc : 0.6561      |       SGD-WPV_train_loss : 211.7239      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6577      |       SGD-WPV_train_loss : 209.4309      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 28.6876      |
# auc is 0.5349296223409439
# | epoch   # 01 :SGD-WPV_train_acc : 0.6561      |       SGD-WPV_train_loss : 215.3458      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6591      |       SGD-WPV_train_loss : 212.9769      |       SGD-WPV_test_acc : 0.6701      |       SGD-WPV_validation_loss : 28.8969      |
# auc is 0.4580262506787653
# | epoch   # 01 :SGD-WPV_train_acc : 0.6564      |       SGD-WPV_train_loss : 214.6673      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6584      |       SGD-WPV_train_loss : 212.5252      |       SGD-WPV_test_acc : 0.6553      |       SGD-WPV_validation_loss : 29.1089      |
# auc is 0.5029788755409683

# %%
def calculate_ates(res,alpha = 0.1):
  ate_true, ate_hat = calculate_ate_ate_estimated(res)
  res = res[res['ps'].between(0+alpha, 1- alpha)]
  ate_true_with_alpha, ate_hat_with_alpha = calculate_ate_ate_estimated(res)
  return [ate_true, ate_hat, ate_true_with_alpha, ate_hat_with_alpha]

all_results = pd.concat(all_ate)
for exp in all_results['exp'].unique(): 
  print("#"*50)
  print(exp)
  print("#"*50)
  exp_results = all_results[all_results['exp'] == exp]
  exp_results.plot(figsize = (20,10))
  plt.show()
  true_ate_abs_resid = np.abs(exp_results['ATE_TRUE_ALL_POPULATION']- exp_results['ATE_HAT_ALL_POPULATION'])
  true_ate_mean = np.mean(true_ate_abs_resid)
  true_ate_std = np.std(true_ate_abs_resid)
  print(F"true ate estimator is {np.round(true_ate_mean,5)} +- {np.round(true_ate_std,5)}")
  true_ate_abs_resid_alpha = np.abs(exp_results['ATE_TRUE_POPULATION_BETWEEN [a,1-a]']- exp_results['ATE_HAT_POPULATION_BETWEEN [a,1-a]'])
  true_ate_mean_alpha = np.mean(true_ate_abs_resid_alpha)
  true_ate_std_alpha = np.std(true_ate_abs_resid_alpha)
  print(F"alpha ate estimator is {np.round(true_ate_mean_alpha,5)} +- {np.round(true_ate_std_alpha,5)}")
# Out:
# ##################################################
# baseline
# ##################################################
# true ate estimator is 0.03307 +- 0.00799
# alpha ate estimator is 0.03315 +- 0.00791
# ##################################################
# entropy
# ##################################################
# true ate estimator is 0.03203 +- 0.01004
# alpha ate estimator is 0.03203 +- 0.01004
# ##################################################
# MCdropout
# ##################################################
# true ate estimator is 0.03035 +- 0.00952
# alpha ate estimator is 0.03035 +- 0.00952
# ##################################################
# SGD-WPV
# ##################################################
# true ate estimator is 0.03309 +- 0.00551
# alpha ate estimator is 0.03309 +- 0.00551

# %%
last_exp = pd.DataFrame()
last_exp['t'] = T
last_exp['ps'] = ps

# %%
plt.figure(figsize=(16, 6))
sns.kdeplot(last_exp[last_exp['t'] == 1]['ps'], shade=True, color="r",label ='T = 1')
sns.kdeplot(last_exp[last_exp['t'] == 0]['ps'], shade=True, color="b", label ='T = 0')
plt.show()

plt.figure(figsize=(16, 6))
sns.kdeplot(last_exp['ps'], shade=True, color="r")
plt.show()
