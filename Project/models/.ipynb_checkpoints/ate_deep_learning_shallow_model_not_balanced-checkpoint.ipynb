# %%
import numpy as np
# !pip install tensorboardcolab
import torch
from torchvision import datasets, transforms
import helper
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import summary
import datetime
import pandas as pd
from collections import OrderedDict
from os import mkdir
from os.path import isdir
from glob import glob
from pathlib import Path
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from google.colab import drive
import seaborn as sns
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Read input data

# %%
ROOT_PATH = Path('/content/drive/My Drive/DL/Project/experiments/ate/')
DATA_PATH = ROOT_PATH/'data/' 
SEED = 42

x = pd.read_csv(DATA_PATH/'X_one_hot.csv')
gestat_simulated = pd.read_csv(DATA_PATH/'gestat10.csv',header = None)[0]
heavier_tween_first = pd.read_csv(DATA_PATH/'heavier_tween_born_first.csv',header = None)[0]
y = pd.read_csv(DATA_PATH/'Y.csv')

# %% [markdown]
# ## Simulate observational study

# %%
def get_simulated_data(x,y,gestat10, w_0, w_h,heavier_tween_first):
    p_heavier =  x@w_0 + w_h*(gestat10.astype('float')*0.1-0.1)
    p_heavier_norm = (p_heavier - p_heavier.min()) / (p_heavier.max() - p_heavier.min())
    t_s = (np.random.random(x.shape[0]) < p_heavier_norm)*1 # t = 1 means heavier
    y_s = []
    birth_order = []
    for i,tween in enumerate(t_s):
        y_s.append(y.values[i,tween])
        if tween == 1: # if the hevier tween 
            is_hevier = heavier_tween_first[i]
        else:
            is_hevier = not heavier_tween_first[i]
        birth_order.append(is_hevier*1)
    temp_x = x.copy()
    temp_x["birth_order"] =  birth_order
    return temp_x,np.array(y_s),t_s

# %% [markdown]
# ## Propensity score model

# %%
class PS_NN(nn.Module):
  def __init__(self):
    super().__init__() 
    self.fc1 = nn.Linear(163, 20) 
    self.fc2 = nn.Linear(20, 20) 
    self.fc3 = nn.Linear(20, 2) 
    self.fc4 = nn.Linear(163, 2) 
    self.softmax = nn.LogSoftmax(dim=1)
    self.regulizer = nn.Dropout(0.01)

  def forward(self, x):
    # x = F.relu(self.fc1(x)) 
    # x = self.regulizer(x) 
    # x = F.relu(self.fc2(x)) 
    # x = self.regulizer(x) 
    # x = F.relu(self.fc3(x)) 
    # x= self.softmax(x)
    x = self.softmax(self.fc4(x))
    return x

# %% [markdown]
# ## Trainer

# %%
from sklearn.model_selection import train_test_split

def get_batch(x,y,batch_size,device):
  batches = np.arange(0,x.shape[0],batch_size)
  for i in range(len(batches)-1):
    inputs, targets = torch.from_numpy(x[batches[i]:batches[i+1],:]), torch.from_numpy(y[batches[i]:batches[i+1]])
    inputs = inputs.to(device).float()
    targets = targets.to(device, dtype=torch.int64)
    yield inputs, targets

class Trainer:
  def __init__(self,model, config):
    self.model = model
    self.model_name = config.model_name
    self.seed = config.seed
    self.lr = config.lr
    self.epochs = config.epochs
    self.save_model = config.save_model
    self.upload_model = config.upload_model
    self.model_weights_path = config.model_weights_path
    self.batch_size =  config.batch_size
    self.dropout_std_n_times = config.dropout_std_n_times
    self.momentum = config.momentum
    self.optimizer = optim.SGD(self.model.parameters(), lr = self.lr, weight_decay = config.weight_decay, momentum=self.momentum)
    self.scheduler = optim.lr_scheduler.StepLR(self.optimizer, step_size=config.step_size, gamma=config.gamma)
    torch.manual_seed(self.seed)
    self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    # class_weights = torch.FloatTensor([0.657,0.342]).to(self.device)
    self.criterion = nn.NLLLoss(reduction='none')
    self.results = {}
    self.sgd_spv_matrix = {}
    self.warmup_epochs = config.warmup_epochs
    self.eps = config.eps
    if torch.cuda.is_available():
      self.model.to(self.device)

  def get_results(self):
    return pd.DataFrame.from_dict(self.results)

  def record(self,epoch,**kwargs):
    epoch = "{:02d}".format(epoch)
    temp = f"| epoch   # {epoch} :"
    for key, value in kwargs.items():
      key = f"{self.model_name}_{key}"
      if not self.results.get(key):
        self.results[key] =[]
      self.results[key].append(value)
      val = '{:.4f}'.format(np.round(value,4))
      temp += f"{key} : {val}      |       "
    print(temp)


  def fit(self,x,y, exp_name): 
    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.12)
    train_accu, test_accu, output_plot = [],[],[]
    for epoch in range(1,self.epochs+1):
      weights_path = Path(f"{self.model_weights_path}/{config.model_name}_{epoch}.pth")
      train_metric, train_loss = self.run_epoch(x_train, y_train, epoch)
      validation_metric, validation_loss = self.val(x_val, y_val,epoch)
      self.record(epoch,
                  train_acc = train_metric,
                  train_loss = train_loss,
                  test_acc = validation_metric,
                  validation_loss = validation_loss)


  def run_epoch(self, x,y,epoch):
    self.model.train()
    train_loss , train_metric = 0, 0
    for batch , (inputs, labels) in enumerate(get_batch(x,y,self.batch_size,self.device)):
      loss = self.get_loss(inputs, labels, batch, epoch)  #self.weighted_loss(images, labels, i, epoch)
      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()
      self.scheduler.step()
      train_loss += self.get_loss(inputs, labels, i, epoch, False).item()
      train_metric += self.calc_accuracy(inputs,labels,return_labels=False)
    accuracy = train_metric/(batch+1)
    return accuracy,train_loss


  def val(self, x,y, epoch):
    self.model.eval()
    val_loss , val_metric = 0, 0
    with torch.no_grad():
      for batch , (inputs, labels) in enumerate(get_batch(x,y,self.batch_size,self.device)):
        acc = self.calc_accuracy(inputs,labels)
        val_metric += acc 
        val_loss += self.get_loss(inputs, labels, batch, epoch, False).item()
    acuuracy = val_metric/(batch+1)
    return acuuracy,val_loss

  def get_loss(self,x, y, batch, epoch,weighted=True):
    loss = self.criterion(self.model(x), y)
    weights = torch.ones(x.size()[0], device= self.device)
    if weighted and (epoch >= self.warmup_epochs + 1) and (self.model_name != 'baseline'):
        epoch_of_weighted_training = epoch - (self.warmup_epochs + 1) 
        weights = self.weighted_loss(x, y,batch, epoch_of_weighted_training) 
    return (loss*weights).mean()
    

  def weighted_loss(self, x, labels, batch, epoch_weighted, is_test=False):
    total_weighted_epochs = self.epochs - self.warmup_epochs
    batch_size = x.size()[0] 
    #row_indexes = [i for i in range(self.batch_size)]
    with torch.no_grad():
      weights = torch.ones(batch_size, device= self.device)

      if self.model_name == 'MCdropout' or is_test:  
        all_p =  torch.zeros((batch_size #self.batch_size,
                              ,self.dropout_std_n_times), device= self.device)
        for i in range(self.dropout_std_n_times):
          p = torch.exp(self.model(x))
          p_true_labels = torch.gather(p, 1, labels.view(-1,1))
          #p_true_labels = p[row_indexes,labels]
          all_p[:,i] = p_true_labels.view(-1)
          weights = all_p.std(axis = 1)

      elif self.model_name == 'entropy':
        log_p = self.model(x)
        weights = -torch.mul(log_p, torch.exp(log_p)).sum(axis = 1)

      elif self.model_name == 'SGD-WPV':
        self.sgd_spv_matrix.setdefault(batch, torch.zeros((batch_size #self.batch_size,
                                                          ,total_weighted_epochs), device= self.device))
        # update_matrix
        p = torch.exp(self.model(x))
        p_true_labels = torch.gather(p, 1, labels.view(-1,1))
        #p_true_labels = p[row_indexes,labels]
        self.sgd_spv_matrix[batch][:,epoch_weighted] = p_true_labels.view(-1)
        if epoch_weighted not in [0,1]:
          indexes = [i for i in range(epoch_weighted)]
          var = self.sgd_spv_matrix[batch][:,indexes].var(axis = 1)
          var +=  var.pow(2)/(len(indexes) -1)
          weights = var.sqrt()
        # else:
        #   weights = torch.ones(x.size()[0], device= self.device) # no history, or no variance -> equal weights
      weights += self.eps
      return (weights)


  def get_ps(self, x):
    with torch.no_grad():
      x = torch.from_numpy(x).to(self.device).float()
      return torch.exp(self.model(x)).cpu().numpy()[:,1]


  def calc_accuracy(self, images, labels, return_labels=False):
    self.model.eval()
    log_ps = self.model(images)
    ps = torch.exp(log_ps)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    acc = torch.mean(equals.type(torch.FloatTensor))
    if return_labels:
      predicted_lables = top_class.view(-1).cpu().tolist()
      ps_labels = torch.gather(ps, 1, labels.view(-1,1))
      self.model.train()
      return acc, predicted_lables, ps_labels.view(-1).cpu().tolist()
    self.model.train()
    return acc


  def save_checkpoint(self,weights_path,loss):
    if (not weights_path.exists()) and self.save_model: 
      torch.save({'model_state_dict': self.model.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),'loss': loss}, weights_path)
      
  def load_checkpoint(self,weights_path,epoch):
    checkpoint = torch.load(weights_path)
    self.model.load_state_dict(checkpoint['model_state_dict'])
    self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    self.model.to(self.device)
    loss = checkpoint['loss']
    print(f"Uploaded weights succesfuly at epoch number {epoch}")
    return loss

# %% [markdown]
# ## Utils

# %%
import time
def change_seed():
  t = 1000 * time.time() # current time in milliseconds
  np.random.seed(int(t) % 2**32)

def calculate_ate_ate_estimated(res):
  ate_hat = (res['y']*res['t']/res['ps'] -res['y']*(1-res['t'])/(1-res['ps'])).mean()
  ate_true = (res['mort_1']-res['mort_0']).mean()
  return ate_true, ate_hat

def calculate_ates(res,alpha = 0.1):
  ate_true, ate_hat = calculate_ate_ate_estimated(res)
  res = res[res['ps'].between(0+alpha, 1- alpha)]
  ate_true_with_alpha, ate_hat_with_alpha = calculate_ate_ate_estimated(res)
  return [ate_true, ate_hat, ate_true_with_alpha, ate_hat_with_alpha]
  # print(F"true ate is {ate_true} and estimated ate is {ate_hat}")


def get_results_df(propensity_score, t,y_simulated,y_all):
  results = pd.DataFrame()
  results['ps'] = propensity_score
  results['t'] = t
  results['y'] = y_simulated 
  return pd.concat([results,y_all], axis = 1)

class Config:  
  def __init__(self, **kwargs):
    for key, value in kwargs.items():
      setattr(self, key, value)

  def add_attributes(self,**kwargs):
    for key, value in kwargs.items():
      setattr(self, key, value)

# %% [markdown]
# ## Config

# %%
MODEL_WEIGHTS_DIR = 'model_weights'
GRAPHS_FOLDER_NAME = 'graphs'
model_weights_dir = f"{ROOT_PATH}{MODEL_WEIGHTS_DIR}" 
graphs_dir = f"{ROOT_PATH}{GRAPHS_FOLDER_NAME}" 
N_EXP = 5

def get_base_config():
  SAVE_TO_CHECKPOINTS = False
  LOAD_CHECKPOINTS = False 
  return Config(
          seed = 2,
          lr = 0.001,
          warmup_epochs = 1,
          epochs = 10,
          step_size=2,
          gamma=0.95,
          eps= 0.001,
          weight_decay=0.01,
          dropout_std_n_times = 15,
          momentum = 0.9,
          save_model = SAVE_TO_CHECKPOINTS,
          upload_model = LOAD_CHECKPOINTS,
          model_weights_path = model_weights_dir,
          batch_size = 16)
  
ate_columns =  ['ATE_TRUE_ALL_POPULATION', 'ATE_HAT_ALL_POPULATION', 'ATE_TRUE_POPULATION_BETWEEN [a,1-a]', 'ATE_HAT_POPULATION_BETWEEN [a,1-a]']
np.random.seed(SEED)
w_0 = np.random.normal(0,0.1,x.shape[1])
w_h = np.random.normal(3,0.1)
seeds = np.random.choice([i for i in range(100)],N_EXP,replace = False)

# %% [markdown]
# ## Run experiments

# %%
from sklearn.metrics import roc_auc_score
all_pop_ate = y['mort_1'].mean()- y['mort_0'].mean()
config = get_base_config()
all_ate = []
for exp in ['baseline','entropy','MCdropout','SGD-WPV']:
  ate = []
  for i in range(N_EXP):
    torch.manual_seed(seeds[i])
    change_seed()
    X,Y,T = get_simulated_data(x,y,gestat_simulated, w_0, w_h,heavier_tween_first)
    X,T = X.values.astype('float64'),T.values.astype('float64')
    config.add_attributes(model_name = exp)
    trainer = Trainer(PS_NN(), config)
    trainer.fit(X,T, exp)
    ps = trainer.get_ps(X) 
    print(F"auc is {roc_auc_score(T, ps)}")
    results = get_results_df(ps, T,Y,y)
    ate.append(calculate_ates(results))
  ate = pd.DataFrame(ate,columns = ate_columns)
  ate['exp'] = exp
  all_ate.append(ate)
# Out:
# | epoch   # 01 :baseline_train_acc : 0.6510      |       baseline_train_loss : 462.8715      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 02 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 03 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 04 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 05 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 06 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 07 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 08 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 09 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# | epoch   # 10 :baseline_train_acc : 0.6535      |       baseline_train_loss : 461.7808      |       baseline_test_acc : 0.6662      |       baseline_validation_loss : 61.7354      |
# auc is 0.5139062001762613
# | epoch   # 01 :baseline_train_acc : 0.6419      |       baseline_train_loss : 469.6920      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 02 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 03 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 04 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 05 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 06 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 07 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 08 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 09 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# | epoch   # 10 :baseline_train_acc : 0.6434      |       baseline_train_loss : 468.7747      |       baseline_test_acc : 0.6585      |       baseline_validation_loss : 63.3329      |
# auc is 0.48149744084387336
# | epoch   # 01 :baseline_train_acc : 0.6574      |       baseline_train_loss : 461.7949      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 02 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 03 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 04 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 05 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 06 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 07 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 08 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 09 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# | epoch   # 10 :baseline_train_acc : 0.6588      |       baseline_train_loss : 460.5161      |       baseline_test_acc : 0.6553      |       baseline_validation_loss : 63.2534      |
# auc is 0.5099788471974993
# | epoch   # 01 :baseline_train_acc : 0.6503      |       baseline_train_loss : 462.8875      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 02 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 03 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 04 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 05 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 06 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 07 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 08 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 09 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# | epoch   # 10 :baseline_train_acc : 0.6566      |       baseline_train_loss : 461.1733      |       baseline_test_acc : 0.6437      |       baseline_validation_loss : 63.4714      |
# auc is 0.5024462361649576
# | epoch   # 01 :baseline_train_acc : 0.6523      |       baseline_train_loss : 463.3684      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 02 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 03 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 04 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 05 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 06 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 07 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 08 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 09 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# | epoch   # 10 :baseline_train_acc : 0.6532      |       baseline_train_loss : 462.6956      |       baseline_test_acc : 0.6411      |       baseline_validation_loss : 63.7264      |
# auc is 0.4976257439390889
# | epoch   # 01 :entropy_train_acc : 0.6504      |       entropy_train_loss : 462.6290      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 02 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 03 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 04 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 05 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 06 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 07 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 08 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 09 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# | epoch   # 10 :entropy_train_acc : 0.6526      |       entropy_train_loss : 461.8603      |       entropy_test_acc : 0.6450      |       entropy_validation_loss : 63.5076      |
# auc is 0.5163348106121524
# | epoch   # 01 :entropy_train_acc : 0.6465      |       entropy_train_loss : 465.5317      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 02 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 03 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 04 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 05 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 06 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 07 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 08 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 09 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# | epoch   # 10 :entropy_train_acc : 0.6494      |       entropy_train_loss : 464.6394      |       entropy_test_acc : 0.6508      |       entropy_validation_loss : 63.4696      |
# auc is 0.48948375258076965
# | epoch   # 01 :entropy_train_acc : 0.6512      |       entropy_train_loss : 461.5829      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 02 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 03 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 04 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 05 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 06 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 07 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 08 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 09 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# | epoch   # 10 :entropy_train_acc : 0.6547      |       entropy_train_loss : 460.3910      |       entropy_test_acc : 0.6514      |       entropy_validation_loss : 63.0099      |
# auc is 0.5201706912990465
# | epoch   # 01 :entropy_train_acc : 0.6435      |       entropy_train_loss : 464.9544      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 02 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 03 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 04 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 05 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 06 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 07 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 08 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 09 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# | epoch   # 10 :entropy_train_acc : 0.6489      |       entropy_train_loss : 463.2502      |       entropy_test_acc : 0.6772      |       entropy_validation_loss : 61.8767      |
# auc is 0.5124686065159111
# | epoch   # 01 :entropy_train_acc : 0.6459      |       entropy_train_loss : 464.2712      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 02 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 03 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 04 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 05 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 06 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 07 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 08 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 09 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# | epoch   # 10 :entropy_train_acc : 0.6469      |       entropy_train_loss : 463.6064      |       entropy_test_acc : 0.6669      |       entropy_validation_loss : 62.4486      |
# auc is 0.5092641562135919
# | epoch   # 01 :MCdropout_train_acc : 0.6410      |       MCdropout_train_loss : 466.0577      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 02 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 03 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 04 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 05 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 06 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 07 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 08 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 09 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# | epoch   # 10 :MCdropout_train_acc : 0.6427      |       MCdropout_train_loss : 465.2566      |       MCdropout_test_acc : 0.6372      |       MCdropout_validation_loss : 63.8262      |
# auc is 0.5158715279637665
# | epoch   # 01 :MCdropout_train_acc : 0.6541      |       MCdropout_train_loss : 463.3656      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 02 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 03 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 04 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 05 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 06 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 07 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 08 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 09 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# | epoch   # 10 :MCdropout_train_acc : 0.6571      |       MCdropout_train_loss : 462.3446      |       MCdropout_test_acc : 0.6772      |       MCdropout_validation_loss : 61.9583      |
# auc is 0.48320264313341466
# | epoch   # 01 :MCdropout_train_acc : 0.6519      |       MCdropout_train_loss : 461.8147      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 02 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 03 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 04 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 05 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 06 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 07 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 08 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 09 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# | epoch   # 10 :MCdropout_train_acc : 0.6553      |       MCdropout_train_loss : 460.6876      |       MCdropout_test_acc : 0.6411      |       MCdropout_validation_loss : 64.0251      |
# auc is 0.5123971923585113
# | epoch   # 01 :MCdropout_train_acc : 0.6502      |       MCdropout_train_loss : 462.8724      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 02 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 03 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 04 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 05 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 06 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 07 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 08 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 09 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# | epoch   # 10 :MCdropout_train_acc : 0.6555      |       MCdropout_train_loss : 460.9333      |       MCdropout_test_acc : 0.6521      |       MCdropout_validation_loss : 63.0788      |
# auc is 0.5044068571741455
# | epoch   # 01 :MCdropout_train_acc : 0.6551      |       MCdropout_train_loss : 460.8582      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 02 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 03 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 04 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 05 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 06 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 07 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 08 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 09 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# | epoch   # 10 :MCdropout_train_acc : 0.6569      |       MCdropout_train_loss : 459.8125      |       MCdropout_test_acc : 0.6579      |       MCdropout_validation_loss : 62.5055      |
# auc is 0.5051884093281417
# | epoch   # 01 :SGD-WPV_train_acc : 0.6589      |       SGD-WPV_train_loss : 457.4404      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6608      |       SGD-WPV_train_loss : 456.4264      |       SGD-WPV_test_acc : 0.6604      |       SGD-WPV_validation_loss : 62.0081      |
# auc is 0.5318335467240238
# | epoch   # 01 :SGD-WPV_train_acc : 0.6505      |       SGD-WPV_train_loss : 465.3248      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6534      |       SGD-WPV_train_loss : 464.5233      |       SGD-WPV_test_acc : 0.6437      |       SGD-WPV_validation_loss : 64.1373      |
# auc is 0.4832713424003088
# | epoch   # 01 :SGD-WPV_train_acc : 0.6527      |       SGD-WPV_train_loss : 461.3878      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6554      |       SGD-WPV_train_loss : 460.3798      |       SGD-WPV_test_acc : 0.6675      |       SGD-WPV_validation_loss : 62.1083      |
# auc is 0.5189196447140692
# | epoch   # 01 :SGD-WPV_train_acc : 0.6600      |       SGD-WPV_train_loss : 456.9949      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6653      |       SGD-WPV_train_loss : 454.9917      |       SGD-WPV_test_acc : 0.6572      |       SGD-WPV_validation_loss : 62.7566      |
# auc is 0.5177677950093778
# | epoch   # 01 :SGD-WPV_train_acc : 0.6453      |       SGD-WPV_train_loss : 464.7548      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 02 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 03 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 04 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 05 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 06 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 07 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 08 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 09 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# | epoch   # 10 :SGD-WPV_train_acc : 0.6474      |       SGD-WPV_train_loss : 464.0813      |       SGD-WPV_test_acc : 0.6463      |       SGD-WPV_validation_loss : 63.2327      |
# auc is 0.5080659029486503

# %%
def calculate_ates(res,alpha = 0.1):
  ate_true, ate_hat = calculate_ate_ate_estimated(res)
  res = res[res['ps'].between(0+alpha, 1- alpha)]
  ate_true_with_alpha, ate_hat_with_alpha = calculate_ate_ate_estimated(res)
  return [ate_true, ate_hat, ate_true_with_alpha, ate_hat_with_alpha]

all_results = pd.concat(all_ate)
for exp in all_results['exp'].unique(): 
  print("#"*50)
  print(exp)
  print("#"*50)
  exp_results = all_results[all_results['exp'] == exp]
  exp_results.plot(figsize = (20,10))
  plt.show()
  true_ate_abs_resid = np.abs(exp_results['ATE_TRUE_ALL_POPULATION']- exp_results['ATE_HAT_ALL_POPULATION'])
  true_ate_mean = np.mean(true_ate_abs_resid)
  true_ate_std = np.std(true_ate_abs_resid)
  print(F"true ate estimator is {np.round(true_ate_mean,5)} +- {np.round(true_ate_std,5)}")
  true_ate_abs_resid_alpha = np.abs(exp_results['ATE_TRUE_POPULATION_BETWEEN [a,1-a]']- exp_results['ATE_HAT_POPULATION_BETWEEN [a,1-a]'])
  true_ate_mean_alpha = np.mean(true_ate_abs_resid_alpha)
  true_ate_std_alpha = np.std(true_ate_abs_resid_alpha)
  print(F"alpha ate estimator is {np.round(true_ate_mean_alpha,5)} +- {np.round(true_ate_std_alpha,5)}")
# Out:
# ##################################################
# baseline
# ##################################################
# true ate estimator is 0.06137 +- 0.01228
# alpha ate estimator is 0.06137 +- 0.01228
# ##################################################
# entropy
# ##################################################
# true ate estimator is 0.06633 +- 0.00954
# alpha ate estimator is 0.06633 +- 0.00954
# ##################################################
# MCdropout
# ##################################################
# true ate estimator is 0.05809 +- 0.00516
# alpha ate estimator is 0.05809 +- 0.00516
# ##################################################
# SGD-WPV
# ##################################################
# true ate estimator is 0.06231 +- 0.00654
# alpha ate estimator is 0.06231 +- 0.00654

# %%
last_exp = pd.DataFrame()
last_exp['t'] = T
last_exp['ps'] = ps

# %%
plt.figure(figsize=(16, 6))
sns.kdeplot(last_exp[last_exp['t'] == 1]['ps'], shade=True, color="r",label ='T = 1')
sns.kdeplot(last_exp[last_exp['t'] == 0]['ps'], shade=True, color="b", label ='T = 0')
plt.show()

plt.figure(figsize=(16, 6))
sns.kdeplot(last_exp['ps'], shade=True, color="r")
plt.show()
